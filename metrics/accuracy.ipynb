# %%
import numpy as np

# %%
def accuracy(y_pred,y_true):

    cnt = 0
    
    y_true , y_pred = np.array(y_true), np.array(y_pred)

    n = len(y_true)

    for x in range(n):

        if y_true[x] == y_pred[x]:

            cnt += 1

    return cnt/n
